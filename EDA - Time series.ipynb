# %%
# !python functions.py
# %load_ext autoreload
# %autoreload 2

# %% [raw]
# Concatinating the stock data set of top technology company in US
# Company like google,Apple,Microsoft,Amazon,Netflix in a sigle dataframe

# %%
from functions import concat_dataset

df = concat_dataset(company_list = ['AAPL_data.csv', 
                                    'GOOGL_data.csv', 
                                    'MSFT_data.csv', 
                                    'AMZN_data.csv',
                                    'NFLX_data.csv'], path = 'dataset')

# %%
df.head()
# Out:
#          date     open     high      low    close     volume  Name
# 0  2013-02-08  67.7142  68.4014  66.8928  67.8542  158168416  AAPL
# 1  2013-02-11  68.0714  69.2771  67.6071  68.5614  129029425  AAPL
# 2  2013-02-12  68.5014  68.9114  66.8205  66.8428  151829363  AAPL
# 3  2013-02-13  66.7442  67.6628  66.1742  66.7156  118721995  AAPL
# 4  2013-02-14  66.3599  67.3771  66.2885  66.6556   88809154  AAPL

# %%
df.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# Name       object
# dtype: object

# %%
df['date'][0]
# Out:
# 0    2013-02-08
# 0    2013-02-08
# 0    2013-02-08
# 0    2013-02-08
# 0    2013-02-08
# Name: date, dtype: object

# %%
from functions import figureplot

# %%
figureplot(df,'date','close','matplot')
# Out:
# ([<matplotlib.lines.Line2D at 0x7fdb6a5b97f0>], Text(0.5, 1.0, 'NFLX'))

# %%
figureplot(df,'date','volume','matplot')
# Out:
# ([<matplotlib.lines.Line2D at 0x7fdb6a3fa160>], Text(0.5, 1.0, 'NFLX'))

# %%
fig = figureplot(df,'date','close','plotly')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3538/4130359650.py in <module>
# ----> 1 fig = figureplot(df,'date','close','plotly')
#       2 fig.show()
#
# ~/project-3/functions.py in figureplot(dataframe, x_axis, y_aixs, choose_plot)
#      37     elif(choose_plot == 'plotly'):
#      38
# ---> 39         return  (px.line(dataframe, x = x_axis, y = y_aixs, title = dataframe['Name'].unique()))
#      40
#      41
#
# ~/project-3/p3env/lib/python3.8/site-packages/plotly/express/_chart_types.py in line(data_frame, x, y, line_group, color, line_dash, hover_name, hover_data, custom_data, text, facet_row, facet_col, facet_col_wrap, facet_row_spacing, facet_col_spacing, error_x, error_x_minus, error_y, error_y_minus, animation_frame, animation_group, category_orders, labels, orientation, color_discrete_sequence, color_discrete_map, line_dash_sequence, line_dash_map, log_x, log_y, range_x, range_y, line_shape, render_mode, title, template, width, height)
#     250     a polyline mark in 2D space.
#     251     """
# --> 252     return make_figure(args=locals(), constructor=go.Scatter)
#     253
#     254
#
# ~/project-3/p3env/lib/python3.8/site-packages/plotly/express/_core.py in make_figure(args, constructor, trace_patch, layout_patch)
#    2117     # Add traces, layout and frames to figure
#    2118     fig.add_traces(frame_list[0]["data"] if len(frame_list) > 0 else [])
# -> 2119     fig.update_layout(layout_patch)
#    2120     if "template" in args and args["template"] is not None:
#    2121         fig.update_layout(template=args["template"], overwrite=True)
#
# ~/project-3/p3env/lib/python3.8/site-packages/plotly/basedatatypes.py in update_layout(self, dict1, overwrite, **kwargs)
#    1401             The Figure object that the update_layout method was called on
#    1402         """
# -> 1403         self.layout.update(dict1, overwrite=overwrite, **kwargs)
#    1404         return self
#    1405
#
# ~/project-3/p3env/lib/python3.8/site-packages/plotly/basedatatypes.py in update(self, dict1, overwrite, **kwargs)
#    5079         if self.figure:
#    5080             with self.figure.batch_update():
# -> 5081                 BaseFigure._perform_update(self, dict1, overwrite=overwrite)
#    5082                 BaseFigure._perform_update(self, kwargs, overwrite=overwrite)
#    5083         else:
#
# ~/project-3/p3env/lib/python3.8/site-packages/plotly/basedatatypes.py in _perform_update(plotly_obj, update_obj, overwrite)
#    3919                 else:
#    3920                     # Assign non-compound value
# -> 3921                     plotly_obj[key] = val
#    3922
#    3923         elif isinstance(plotly_obj, tuple):
#
# ~/project-3/p3env/lib/python3.8/site-packages/plotly/basedatatypes.py in __setitem__(self, prop, value)
#    5808         if len(prop_tuple) != 1 or not isinstance(prop_tuple[0], string_types):
#    5809             # Let parent handle non-scalar non-string cases
# -> 5810             super(BaseLayoutHierarchyType, self).__setitem__(prop, value)
#    5811             return
#    5812         else:
#
# ~/project-3/p3env/lib/python3.8/site-packages/plotly/basedatatypes.py in __setitem__(self, prop, value)
#    4857             res._validate = self._validate
#    4858
# -> 4859             res[prop[-1]] = value
#    4860
#    4861     def __setattr__(self, prop, value):
#
# ~/project-3/p3env/lib/python3.8/site-packages/plotly/basedatatypes.py in __setitem__(self, prop, value)
#    4817                 # ### Handle simple property ###
#    4818                 else:
# -> 4819                     self._set_prop(prop, value)
#    4820             else:
#    4821                 # Make sure properties dict is initialized
#
# ~/project-3/p3env/lib/python3.8/site-packages/plotly/basedatatypes.py in _set_prop(self, prop, val)
#    5161                 return
#    5162             else:
# -> 5163                 raise err
#    5164
#    5165         # val is None
#
# ~/project-3/p3env/lib/python3.8/site-packages/plotly/basedatatypes.py in _set_prop(self, prop, val)
#    5156
#    5157         try:
# -> 5158             val = validator.validate_coerce(val)
#    5159         except ValueError as err:
#    5160             if self._skip_invalid:
#
# ~/project-3/p3env/lib/python3.8/site-packages/_plotly_utils/basevalidators.py in validate_coerce(self, v)
#    1084                     v = str(v)
#    1085                 else:
# -> 1086                     self.raise_invalid_val(v)
#    1087
#    1088             if self.no_blank and len(v) == 0:
#
# ~/project-3/p3env/lib/python3.8/site-packages/_plotly_utils/basevalidators.py in raise_invalid_val(self, v, inds)
#     288                 name += "[" + str(i) + "]"
#     289
# --> 290         raise ValueError(
#     291             """
#     292     Invalid value of type {typ} received for the '{name}' property of {pname}
#
# ValueError:
#     Invalid value of type 'numpy.ndarray' received for the 'text' property of layout.title
#         Received value: array(['AAPL'], dtype=object)
#
#     The 'text' property is a string and must be specified as:
#       - A string
#       - A number that will be converted to a string
